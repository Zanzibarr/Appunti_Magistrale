# %% [markdown]
# # Comparison of classifiers on simulated data

# %%
from sklearn.datasets import make_moons, make_circles, make_classification
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from matplotlib.colors import ListedColormap

# %% [markdown]
# The following are 3 useful functions for plotting a dataset (only training, or all data split into training and test) and the decision boundary of a model and the data

# %%
def plot_dataset_train(X, X_train, y_train):
    h = 0.02
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(["#FF0000", "#0000FF"])
    ax = plt.subplot(1,1,1)
    ax.set_title("Input data")
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k")
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())

# %%
def plot_dataset(X, X_train, y_train, X_test, y_test):
    h = 0.02
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(["#FF0000", "#0000FF"])
    ax = plt.subplot(1,1,1)
    ax.set_title("Input data")
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k")
    # Plot the testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.2, edgecolors="k")
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())

# %%
def plot_model(input_model, X, X_train, X_test, y_train, y_test):
    h = 0.02
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(["#FF0000", "#0000FF"])
    ax = plt.subplot(1,1,1)
    ax.set_title("Model decision boundary")
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    if hasattr(input_model, "decision_function"):
        Z = input_model.decision_function(np.c_[xx.ravel(), yy.ravel()])
    else:
        Z = input_model.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, cmap=cm, alpha=0.8)

    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k")
    # Plot the testing points
    ax.scatter( X_test[:, 0], X_test[:, 1],c=y_test,
    cmap=cm_bright, edgecolors="k", alpha=0.2)

    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())

# %% [markdown]
# Let's generate an almost linearly separable dataset and run the perceptron first, than SVM, then a NN with default parameters

# %%
X, y = make_classification(
    n_features=2, n_redundant=0, n_informative=2, random_state=1, n_clusters_per_class=1
)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)

X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.4, random_state=42)

# %% [markdown]
# Let's plot the training dataset.

# %%
plot_dataset_train(X, X_train, y_train)

# %% [markdown]
# Let's now print all data (training and testing)

# %%
plot_dataset(X, X_train, y_train, X_test, y_test)

# %% [markdown]
# Now let's learn a perceptron, plot its decision boundary, and print the error on traning and on testing.

# %%
numero_di_matricola = 2122187

perc_model = Perceptron(random_state=numero_di_matricola)
perc_model.fit(X_train, y_train)

# print the decision boundary
plot_model(perc_model, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-perc_model.score(X_train, y_train))
print("Generalization error: ", 1-perc_model.score(X_test, y_test))
# Out:
# Training error:  0.050000000000000044
# Generalization error:  0.15000000000000002

# %% [markdown]
# Let's do the same for SVM.

# %%
svm_model = SVC(random_state=numero_di_matricola, kernel="linear")
svm_model.fit(X_train, y_train)

plot_model(svm_model, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-svm_model.score(X_train, y_train))
print("Generalization error: ", 1-svm_model.score(X_test, y_test))
# Out:
# Training error:  0.050000000000000044
# Generalization error:  0.050000000000000044

# %% [markdown]
# Let's try with a NN.

# %%
nn_model = MLPClassifier(random_state=numero_di_matricola, max_iter=1000)
nn_model.fit(X_train, y_train)

plot_model(nn_model, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-nn_model.score(X_train, y_train))
print("Generalization error: ", 1-nn_model.score(X_test, y_test))
# Out:
# Training error:  0.01666666666666672
# Generalization error:  0.07499999999999996

# %% [markdown]
# Let's try now with some more complex dataset.

# %%
X, y = make_moons(noise=0.3, random_state=0)

X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.4, random_state=42)

# %% [markdown]
# Let's plot the training data.

# %%
plot_dataset_train(X, X_train, y_train)

# %% [markdown]
# Let's plot all the data.

# %%
plot_dataset(X, X_train, y_train, X_test, y_test)

# %% [markdown]
# Let's run the perceptron.

# %%
perc_model_2 = Perceptron(random_state=numero_di_matricola)
perc_model_2.fit(X_train, y_train)

# print the decision boundary
plot_model(perc_model_2, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-perc_model_2.score(X_train, y_train))
print("Generalization error: ", 1-perc_model_2.score(X_test, y_test))
# Out:
# Training error:  0.23333333333333328
# Generalization error:  0.125

# %% [markdown]
# Let's run the SVM

# %%
svm_model_2 = SVC(random_state=numero_di_matricola, kernel="linear")
svm_model_2.fit(X_train, y_train)

plot_model(svm_model_2, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-svm_model_2.score(X_train, y_train))
print("Generalization error: ", 1-svm_model_2.score(X_test, y_test))
# Out:
# Training error:  0.16666666666666663
# Generalization error:  0.125

# %% [markdown]
# Let's try the NN

# %%
nn_model_2 = MLPClassifier(random_state=numero_di_matricola, max_iter=10000)
nn_model_2.fit(X_train, y_train)

plot_model(nn_model_2, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-nn_model_2.score(X_train, y_train))
print("Generalization error: ", 1-nn_model_2.score(X_test, y_test))
# Out:
# Training error:  0.01666666666666672
# Generalization error:  0.050000000000000044

# %% [markdown]
# Another interesting dataset

# %%
X, y= make_circles(noise=0.2, factor=0.5, random_state=1)

X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.4, random_state=42)

# %% [markdown]
# Let's plot the training data.

# %%
plot_dataset_train(X, X_train, y_train)

# %% [markdown]
# Let's plot all the data.

# %%
plot_dataset(X, X_train, y_train, X_test, y_test)

# %% [markdown]
# Let's run the perceptron

# %%
perc_model_3 = Perceptron(random_state=numero_di_matricola)
perc_model_3.fit(X_train, y_train)

# print the decision boundary
plot_model(perc_model_3, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-perc_model_3.score(X_train, y_train))
print("Generalization error: ", 1-perc_model_3.score(X_test, y_test))
# Out:
# Training error:  0.5
# Generalization error:  0.525

# %% [markdown]
# Let's run the SVM

# %%
svm_model_3 = SVC(random_state=numero_di_matricola, kernel="linear")
svm_model_3.fit(X_train, y_train)

plot_model(svm_model_3, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-svm_model_3.score(X_train, y_train))
print("Generalization error: ", 1-svm_model_3.score(X_test, y_test))
# Out:
# Training error:  0.43333333333333335
# Generalization error:  0.6

# %% [markdown]
# Let's run the NN

# %%
nn_model_3 = MLPClassifier(random_state=numero_di_matricola, max_iter=1000)
nn_model_3.fit(X_train, y_train)

plot_model(nn_model_3, X, X_train, X_test, y_train, y_test)

print("Training error: ", 1-nn_model_3.score(X_train, y_train))
print("Generalization error: ", 1-nn_model_3.score(X_test, y_test))
# Out:
# Training error:  0.050000000000000044
# Generalization error:  0.125
